# %%
from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
import matplotlib.pyplot as plt

# reading the image
img = imread('data/game001/snapshot-00373.jpg')
plt.axis("off")
plt.imshow(img);

# %%
resized_img = resize(img, (img.shape[0]/2, img.shape[1]/2))
plt.axis("off")
plt.imshow(resized_img)
print(resized_img.shape)
# Out:
# (360, 640, 3)

# %%
fd, hog_image = hog(resized_img, orientations=9, pixels_per_cell=(8, 8),
                	cells_per_block=(2, 2), visualize=True, multichannel=True)
plt.axis("off")
plt.imshow(hog_image, cmap="gray")

# %%
import skimage.feature


canny_image = skimage.feature.canny(resized_img)
plt.axis("off")
plt.imshow(canny_image, cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-b43372499e24> in <module>
#       2
#       3
# ----> 4 canny_image = skimage.feature.canny(resized_img)
#       5 plt.axis("off")
#       6 plt.imshow(canny_image, cmap="gray")
#
# ~/fun/go-vision/.venv/lib/python3.8/site-packages/skimage/feature/_canny.py in canny(image, sigma, low_threshold, high_threshold, mask, use_quantiles)
#     155     # because who knows what lies beyond the edge of the image?
#     156     #
# --> 157     check_nD(image, 2)
#     158     dtype_max = dtype_limits(image, clip_negative=False)[1]
#     159
#
# ~/fun/go-vision/.venv/lib/python3.8/site-packages/skimage/_shared/utils.py in check_nD(array, ndim, arg_name)
#     318         raise ValueError(msg_empty_array % (arg_name))
#     319     if not array.ndim in ndim:
# --> 320         raise ValueError(msg_incorrect_dim % (arg_name, '-or-'.join([str(n) for n in ndim])))
#     321
#     322
#
# ValueError: The parameter `image` must be a 2-dimensional array

# %%
720/30
# Out:
# 24.0

# %%
24*8
# Out:
# 192

# %%
1280/30
# Out:
# 42.666666666666664

# %%
1280/24
# Out:
# 53.333333333333336

# %%
1280/16
# Out:
# 80.0
